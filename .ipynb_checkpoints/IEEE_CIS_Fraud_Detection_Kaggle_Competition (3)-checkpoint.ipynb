# %% [markdown]
# # IEEE_CIS Fraud Detection Kaggle Competition

# %% [markdown]
# ## Background

# %% [markdown]
# In this competition you are predicting the probability that an online transaction is fraudulent, as denoted by the binary target isFraud.
#
# The data is broken into two files identity and transaction, which are joined by TransactionID. Not all transactions have corresponding identity information.
#
# **Categorical Features - Transaction**
# ProductCD
# card1 - card6
# addr1, addr2
# P_emaildomain
# R_emaildomain
# M1 - M9
#
# **Categorical Features - Identity**
# DeviceType
# DeviceInfo
# id_12 - id_38
# The TransactionDT feature is a timedelta from a given reference datetime (not an actual timestamp).
#
# **Files**
# train_{transaction, identity}.csv - the training set
# test_{transaction, identity}.csv - the test set (you must predict the isFraud value for these observations)
# sample_submission.csv - a sample submission file in the correct format

# %% [markdown]
# # Required Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV


from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

from sklearn import preprocessing

# %% [markdown]
# # Load Data

# %%
# Transaction CSVs
train_transaction = pd.read_csv('train_transaction.csv')
test_transaction = pd.read_csv('test_transaction.csv')

# Identity CSVs - These will be merged onto the transactions to create additional features
train_identity = pd.read_csv('train_identity.csv')
test_identity = pd.read_csv('test_identity.csv')

# Sample Submissions
ss = pd.read_csv('sample_submission.csv')

print('train_transaction shape is {}'.format(train_transaction.shape))
print('test_transaction shape is {}'.format(test_transaction.shape))
print('train_identity shape is {}'.format(train_identity.shape))
print('test_identity shape is {}'.format(test_identity.shape))
# Out:
# train_transaction shape is (590540, 394)
# test_transaction shape is (506691, 393)
# train_identity shape is (144233, 41)
# test_identity shape is (141907, 41)

# %% [markdown]
# ## Join transaction and identity data

# %%
train = pd.merge(train_transaction, train_identity, on='TransactionID', how='left')
test = pd.merge(test_transaction, test_identity, on='TransactionID', how='left')

# %% [markdown]
# ## Reduce Memory Usage

# %%
del train_transaction, train_identity, test_identity, test_transaction

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

train=reduce_mem_usage(train)
test=reduce_mem_usage(test)
# Out:
# Mem. usage decreased to 650.48 Mb (66.8% reduction)
# Mem. usage decreased to 565.37 Mb (66.3% reduction)

# %% [markdown]
# ## Feature Engineering for Dubious Email Domains

# %%
train['P_isproton']=(train['P_emaildomain']=='protonmail.com')
train['R_isproton']=(train['R_emaildomain']=='protonmail.com')
test['P_isproton']=(test['P_emaildomain']=='protonmail.com')
test['R_isproton']=(test['R_emaildomain']=='protonmail.com')

train['P_anonymous']=(train['P_emaildomain']=='anonymous.com')
train['R_anonymous']=(train['R_emaildomain']=='anonymous.com')
test['P_anonymous']=(test['P_emaildomain']=='anonymous.com')
test['R_anonymous']=(test['R_emaildomain']=='anonymous.com')

# %% [markdown]
# ## Feature Engineering for Transaction Day of Week and Hour of Day

# %%
train['Transaction_day_of_week'] = np.floor((train['TransactionDT'] / (3600 * 24) - 1) % 7)
test['Transaction_day_of_week'] = np.floor((test['TransactionDT'] / (3600 * 24) - 1) % 7)

train['Transaction_hour_of_day'] = np.floor(train['TransactionDT'] / 3600) % 24
test['Transaction_hour_of_day'] = np.floor(test['TransactionDT'] / 3600) % 24

train['TransactionAmt_decimal'] = ((train['TransactionAmt'] - train['TransactionAmt'].astype(int)) * 1000).astype(int)
test['TransactionAmt_decimal'] = ((test['TransactionAmt'] - test['TransactionAmt'].astype(int)) * 1000).astype(int)

# %% [markdown]
# ## Cleaning up *device_name* column

# %%
def setDevice(df):
    df['DeviceInfo'] = df['DeviceInfo'].fillna('unknown_device').str.lower()
    
    df['device_name'] = df['DeviceInfo'].str.split('/', expand=True)[0]

    df.loc[df['device_name'].str.contains('SM', na=False), 'device_name'] = 'Samsung'
    df.loc[df['device_name'].str.contains('SAMSUNG', na=False), 'device_name'] = 'Samsung'
    df.loc[df['device_name'].str.contains('GT-', na=False), 'device_name'] = 'Samsung'
    df.loc[df['device_name'].str.contains('Moto G', na=False), 'device_name'] = 'Motorola'
    df.loc[df['device_name'].str.contains('Moto', na=False), 'device_name'] = 'Motorola'
    df.loc[df['device_name'].str.contains('moto', na=False), 'device_name'] = 'Motorola'
    df.loc[df['device_name'].str.contains('LG-', na=False), 'device_name'] = 'LG'
    df.loc[df['device_name'].str.contains('rv:', na=False), 'device_name'] = 'RV'
    df.loc[df['device_name'].str.contains('HUAWEI', na=False), 'device_name'] = 'Huawei'
    df.loc[df['device_name'].str.contains('ALE-', na=False), 'device_name'] = 'Huawei'
    df.loc[df['device_name'].str.contains('-L', na=False), 'device_name'] = 'Huawei'
    df.loc[df['device_name'].str.contains('Blade', na=False), 'device_name'] = 'ZTE'
    df.loc[df['device_name'].str.contains('BLADE', na=False), 'device_name'] = 'ZTE'
    df.loc[df['device_name'].str.contains('Linux', na=False), 'device_name'] = 'Linux'
    df.loc[df['device_name'].str.contains('XT', na=False), 'device_name'] = 'Sony'
    df.loc[df['device_name'].str.contains('HTC', na=False), 'device_name'] = 'HTC'
    df.loc[df['device_name'].str.contains('ASUS', na=False), 'device_name'] = 'Asus'

    df.loc[df.device_name.isin(df.device_name.value_counts()[df.device_name.value_counts() < 200].index), 'device_name'] = "Others"
    df['had_id'] = 1
    
    return df

train=setDevice(train)
test=setDevice(test)

# %%
train.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
#
#    card2  card3       card4  card5  ...                     DeviceInfo  \
# 0    NaN  150.0    discover  142.0  ...                 unknown_device
# 1  404.0  150.0  mastercard  102.0  ...                 unknown_device
# 2  490.0  150.0        visa  166.0  ...                 unknown_device
# 3  567.0  150.0  mastercard  117.0  ...                 unknown_device
# 4  514.0  150.0  mastercard  102.0  ...  samsung sm-g892a build/nrd90m
#
#    P_isproton  R_isproton  P_anonymous  R_anonymous Transaction_day_of_week  \
# 0       False       False        False        False                     0.0
# 1       False       False        False        False                     0.0
# 2       False       False        False        False                     0.0
# 3       False       False        False        False                     0.0
# 4       False       False        False        False                     0.0
#
#   Transaction_hour_of_day  TransactionAmt_decimal     device_name  had_id
# 0                     0.0                     500  unknown_device       1
# 1                     0.0                       0  unknown_device       1
# 2                     0.0                       0  unknown_device       1
# 3                     0.0                       0  unknown_device       1
# 4                     0.0                       0          Others       1
#
# [5 rows x 443 columns]

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Drop columns with >80% missing values

# %%
perc_thresh = .20
thresh_train = len(train) * perc_thresh
train = train.dropna(thresh = thresh_train, axis = 'columns')

print('train shape is {}'.format(train.shape))
# Out:
# train shape is (590540, 369)

# %%
cols_to_keep = [x for x in train.columns if x != 'isFraud']
test = test[cols_to_keep]
print('test shape is {}'.format(test.shape))
# Out:
# test shape is (506691, 368)

# %%
list(train.columns)
# Out:
# ['TransactionID',
#  'isFraud',
#  'TransactionDT',
#  'TransactionAmt',
#  'ProductCD',
#  'card1',
#  'card2',
#  'card3',
#  'card4',
#  'card5',
#  'card6',
#  'addr1',
#  'addr2',
#  'dist1',
#  'P_emaildomain',
#  'R_emaildomain',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'D10',
#  'D11',
#  'D15',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30',
#  'V31',
#  'V32',
#  'V33',
#  'V34',
#  'V35',
#  'V36',
#  'V37',
#  'V38',
#  'V39',
#  'V40',
#  'V41',
#  'V42',
#  'V43',
#  'V44',
#  'V45',
#  'V46',
#  'V47',
#  'V48',
#  'V49',
#  'V50',
#  'V51',
#  'V52',
#  'V53',
#  'V54',
#  'V55',
#  'V56',
#  'V57',
#  'V58',
#  'V59',
#  'V60',
#  'V61',
#  'V62',
#  'V63',
#  'V64',
#  'V65',
#  'V66',
#  'V67',
#  'V68',
#  'V69',
#  'V70',
#  'V71',
#  'V72',
#  'V73',
#  'V74',
#  'V75',
#  'V76',
#  'V77',
#  'V78',
#  'V79',
#  'V80',
#  'V81',
#  'V82',
#  'V83',
#  'V84',
#  'V85',
#  'V86',
#  'V87',
#  'V88',
#  'V89',
#  'V90',
#  'V91',
#  'V92',
#  'V93',
#  'V94',
#  'V95',
#  'V96',
#  'V97',
#  'V98',
#  'V99',
#  'V100',
#  'V101',
#  'V102',
#  'V103',
#  'V104',
#  'V105',
#  'V106',
#  'V107',
#  'V108',
#  'V109',
#  'V110',
#  'V111',
#  'V112',
#  'V113',
#  'V114',
#  'V115',
#  'V116',
#  'V117',
#  'V118',
#  'V119',
#  'V120',
#  'V121',
#  'V122',
#  'V123',
#  'V124',
#  'V125',
#  'V126',
#  'V127',
#  'V128',
#  'V129',
#  'V130',
#  'V131',
#  'V132',
#  'V133',
#  'V134',
#  'V135',
#  'V136',
#  'V137',
#  'V167',
#  'V168',
#  'V169',
#  'V170',
#  'V171',
#  'V172',
#  'V173',
#  'V174',
#  'V175',
#  'V176',
#  'V177',
#  'V178',
#  'V179',
#  'V180',
#  'V181',
#  'V182',
#  'V183',
#  'V184',
#  'V185',
#  'V186',
#  'V187',
#  'V188',
#  'V189',
#  'V190',
#  'V191',
#  'V192',
#  'V193',
#  'V194',
#  'V195',
#  'V196',
#  'V197',
#  'V198',
#  'V199',
#  'V200',
#  'V201',
#  'V202',
#  'V203',
#  'V204',
#  'V205',
#  'V206',
#  'V207',
#  'V208',
#  'V209',
#  'V210',
#  'V211',
#  'V212',
#  'V213',
#  'V214',
#  'V215',
#  'V216',
#  'V217',
#  'V218',
#  'V219',
#  'V220',
#  'V221',
#  'V222',
#  'V223',
#  'V224',
#  'V225',
#  'V226',
#  'V227',
#  'V228',
#  'V229',
#  'V230',
#  'V231',
#  'V232',
#  'V233',
#  'V234',
#  'V235',
#  'V236',
#  'V237',
#  'V238',
#  'V239',
#  'V240',
#  'V241',
#  'V242',
#  'V243',
#  'V244',
#  'V245',
#  'V246',
#  'V247',
#  'V248',
#  'V249',
#  'V250',
#  'V251',
#  'V252',
#  'V253',
#  'V254',
#  'V255',
#  'V256',
#  'V257',
#  'V258',
#  'V259',
#  'V260',
#  'V261',
#  'V262',
#  'V263',
#  'V264',
#  'V265',
#  'V266',
#  'V267',
#  'V268',
#  'V269',
#  'V270',
#  'V271',
#  'V272',
#  'V273',
#  'V274',
#  'V275',
#  'V276',
#  'V277',
#  'V278',
#  'V279',
#  'V280',
#  'V281',
#  'V282',
#  'V283',
#  'V284',
#  'V285',
#  'V286',
#  'V287',
#  'V288',
#  'V289',
#  'V290',
#  'V291',
#  'V292',
#  'V293',
#  'V294',
#  'V295',
#  'V296',
#  'V297',
#  'V298',
#  'V299',
#  'V300',
#  'V301',
#  'V302',
#  'V303',
#  'V304',
#  'V305',
#  'V306',
#  'V307',
#  'V308',
#  'V309',
#  'V310',
#  'V311',
#  'V312',
#  'V313',
#  'V314',
#  'V315',
#  'V316',
#  'V317',
#  'V318',
#  'V319',
#  'V320',
#  'V321',
#  'id_01',
#  'id_02',
#  'id_05',
#  'id_06',
#  'id_11',
#  'id_12',
#  'id_13',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_19',
#  'id_20',
#  'id_28',
#  'id_29',
#  'id_31',
#  'id_35',
#  'id_36',
#  'id_37',
#  'id_38',
#  'DeviceType',
#  'DeviceInfo',
#  'P_isproton',
#  'R_isproton',
#  'P_anonymous',
#  'R_anonymous',
#  'Transaction_day_of_week',
#  'Transaction_hour_of_day',
#  'TransactionAmt_decimal',
#  'device_name',
#  'had_id']

# %% [markdown]
# ## Fill N/A with -999

# %%
train = train.fillna(-999)
test = test.fillna(-999)

# %% [markdown]
# ## Prepare data for validation / modeling

# %%
X = train.drop(['isFraud','TransactionID','TransactionDT'],axis='columns')
X.head()
# Out:
#    TransactionAmt ProductCD  card1  card2  card3       card4  card5   card6  \
# 0            68.5         W  13926 -999.0  150.0    discover  142.0  credit
# 1            29.0         W   2755  404.0  150.0  mastercard  102.0  credit
# 2            59.0         W   4663  490.0  150.0        visa  166.0   debit
# 3            50.0         W  18132  567.0  150.0  mastercard  117.0   debit
# 4            50.0         H   4497  514.0  150.0  mastercard  102.0  credit
#
#    addr1  addr2  ...                     DeviceInfo P_isproton R_isproton  \
# 0  315.0   87.0  ...                 unknown_device      False      False
# 1  325.0   87.0  ...                 unknown_device      False      False
# 2  330.0   87.0  ...                 unknown_device      False      False
# 3  476.0   87.0  ...                 unknown_device      False      False
# 4  420.0   87.0  ...  samsung sm-g892a build/nrd90m      False      False
#
#    P_anonymous  R_anonymous  Transaction_day_of_week  Transaction_hour_of_day  \
# 0        False        False                      0.0                      0.0
# 1        False        False                      0.0                      0.0
# 2        False        False                      0.0                      0.0
# 3        False        False                      0.0                      0.0
# 4        False        False                      0.0                      0.0
#
#    TransactionAmt_decimal     device_name  had_id
# 0                     500  unknown_device       1
# 1                       0  unknown_device       1
# 2                       0  unknown_device       1
# 3                       0  unknown_device       1
# 4                       0          Others       1
#
# [5 rows x 366 columns]

# %%
test = test.drop(['TransactionID','TransactionDT'],axis='columns')
test.head()
# Out:
#    TransactionAmt ProductCD  card1  card2  card3       card4  card5  card6  \
# 0       31.953125         W  10409  111.0  150.0        visa  226.0  debit
# 1       49.000000         W   4272  111.0  150.0        visa  226.0  debit
# 2      171.000000         W   4476  574.0  150.0        visa  226.0  debit
# 3      285.000000         W  10989  360.0  150.0        visa  166.0  debit
# 4       67.937500         W  18018  452.0  150.0  mastercard  117.0  debit
#
#    addr1  addr2  ...      DeviceInfo P_isproton R_isproton  P_anonymous  \
# 0  170.0   87.0  ...  unknown_device      False      False        False
# 1  299.0   87.0  ...  unknown_device      False      False        False
# 2  472.0   87.0  ...  unknown_device      False      False        False
# 3  205.0   87.0  ...  unknown_device      False      False        False
# 4  264.0   87.0  ...  unknown_device      False      False        False
#
#    R_anonymous  Transaction_day_of_week  Transaction_hour_of_day  \
# 0        False                      2.0                      0.0
# 1        False                      2.0                      0.0
# 2        False                      2.0                      0.0
# 3        False                      2.0                      0.0
# 4        False                      2.0                      0.0
#
#    TransactionAmt_decimal     device_name  had_id
# 0                     953  unknown_device       1
# 1                       0  unknown_device       1
# 2                       0  unknown_device       1
# 3                       0  unknown_device       1
# 4                     937  unknown_device       1
#
# [5 rows x 366 columns]

# %%
y = train['isFraud']

# %% [markdown]
# ## Encode categorical variables

# %%
for f in X.columns:
    if X[f].dtype=='object' or test[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X[f].values) + list(test[f].values))
        X[f] = lbl.transform(list(X[f].values))
        test[f] = lbl.transform(list(test[f].values))

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Split dataset into training set and validation set

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Build Models

# %% [markdown]
# ### AdaBoost Classifier

# %%
ABC = AdaBoostClassifier(
    n_estimators=500,
    learning_rate=1)
ABC.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1,
#           n_estimators=500, random_state=None)

# %%
#y_val_pred = ABC.predict(X_val)
y_val_pred_proba = ABC.predict_proba(X_val)

# %% [markdown]
# ### ROC Curve

# %%
# Evaluate test-set roc_auc_score
ada_roc_auc = roc_auc_score(y_val, y_val_pred_proba[:,1])

# Print roc_auc_score
print('ROC AUC score: {:.4f}'.format(ada_roc_auc))
# Out:
# ROC AUC score: 0.8980

# %%
fpr, tpr, thresholds = roc_curve(y_val, y_val_pred_proba[:,1])

# %%
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, "b:", label=label, linewidth=2)
    plt.plot([0, 1], [0, 1], 'k--') # dashed diagonal
    plt.title('ROC Curve')
    plt.legend()

# %%
plot_roc_curve(fpr, tpr, label='AdaBoost Classifier')
plt.show()

# %% [markdown]
# ### Hyperparameter Tuning

# %%
param_grid = {
 'n_estimators': [500,750],
 'learning_rate' : [.01, .1, 1],
 }

ABC = AdaBoostClassifier()

grid_search = GridSearchCV(ABC, param_grid, 
                           cv=3, scoring='roc_auc',
                           n_jobs = -1, verbose=True)
grid_search.fit(X_train, y_train)

# %%
grid_search.best_params_

# %%
grid_search.best_score_

# %% [markdown]
# ### Best Model Thus Far

# %% [markdown]
# Drop columns with >5% missing.
#
# AdaBoost Classifier
# {'learning_rate': 1, 'n_estimators': 750}
#
# Validation AUC: 0.8986

# %% [markdown]
# # Build Final Predictions

# %% [markdown]
# ## Train and Fit on Full Training Data

# %%
ABC = AdaBoostClassifier(
    n_estimators=500,
    learning_rate=1)
ABC.fit(X, y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1,
#           n_estimators=500, random_state=None)

# %%
#y_test_pred = ABC.predict(test)
y_test_pred_proba = ABC.predict_proba(test)

# %% [markdown]
# ## Write Output

# %%
ss['isFraud'] = y_test_pred_proba[:,1]
ss.to_csv('AdaBoost Model v6.csv',index=False)

# %% [markdown]
# # EDA and Imrovements

# %% [markdown]
# ## What features were seemingly important?

# %%
importances = pd.Series(ABC.feature_importances_, index = X.columns).sort_values()
importances.plot(kind = 'barh',figsize=[18,80]);

# %% [markdown]
# ## Let's compare distributions of Fraudulent and Non-Fraudulent Transactions for some of the important variables

# %%
plt.figure(figsize=(14,6))
sns.distplot(X[y==0].card1,kde=True,label = 'not fraud')
sns.distplot(X[y==1].card1,kde=True,color='red',label = 'fraud')
plt.legend();

# %%
plt.figure(figsize=(14,6))
sns.distplot(X[y==0].card2,kde=True,label = 'not fraud')
sns.distplot(X[y==1].card2,kde=True,color='red',label = 'fraud')
plt.legend();

# %%
plt.figure(figsize=(14,6))
sns.distplot(np.log10(X[y==0].TransactionAmt),kde=True,label = 'not fraud')
sns.distplot(np.log10(X[y==1].TransactionAmt),kde=True,color='red',label = 'fraud')
plt.legend();

# %%
plt.figure(figsize=(14,6))
sns.distplot(X[y==0].C14,kde=True,label = 'not fraud')
sns.distplot(X[y==1].C14,kde=True,color='red',label = 'fraud')
plt.legend();

# %%
plt.figure(figsize=(14,6))
sns.distplot(X[y==0].C1,kde=True,label = 'not fraud')
sns.distplot(X[y==1].C1,kde=True,color='red',label = 'fraud')
plt.legend();

# %%
plt.figure(figsize=(14,6))
sns.distplot(X[y==0].ProductCD,kde=True,label = 'not fraud')
sns.distplot(X[y==1].ProductCD,kde=True,color='red',label = 'fraud')
plt.legend();

# %%
plt.figure(figsize=(14,6))
sns.distplot(X[y==0].D1,kde=True,label = 'not fraud')
sns.distplot(X[y==1].D1,kde=True,color='red',label = 'fraud')
plt.legend();

# %%
sns.distplot(X.TransactionDT, kde=False, label = 'train set')
sns.distplot(test.TransactionDT,kde=False, color='red',label = 'test set')
plt.legend();

# %% [markdown]
# **We see that the dataset was split (Train and Test) by using the TransactionDT column. We should remove this from model training!**

# %%
sns.distplot(X.TransactionID, kde=False, label = 'train set')
sns.distplot(test.TransactionID,kde=False, color='red',label = 'test set')
plt.legend();

# %% [markdown]
# **We see the same split with the TransactionID column. This can also be removed from model training**
